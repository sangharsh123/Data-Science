# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fifa=pd.read_csv("players_20.csv")
fifa
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/200002
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18478     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18479     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18480     252332  https://sofifa.com/player/252332/wei-zhang/200002
# 18481     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18482     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club_name
# league_name
# league_rank
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
fifa.shape
# Out:
# (18483, 106)

# %%
fifa.nationality.value_counts()[0:5]
# Out:
# England      1670
# Germany      1218
# Spain        1045
# France       1004
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa.nationality.value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(10,5))
plt.bar(fifa.nationality.value_counts()[0:10].keys(),list(fifa.nationality.value_counts()[0:10]), color='g')
# Out:
# <BarContainer object of 10 artists>

# %%
fifa.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg   league_rank  \
# count   18483.000000  18483.000000  18483.000000  18483.000000  18243.000000
# mean   219768.374885     25.283071    181.348212     75.259049      1.371430
# std     28047.535516      4.656790      6.760648      7.053023      0.782132
# min        41.000000     16.000000    155.000000     50.000000      0.000000
# 25%    204495.500000     22.000000    177.000000     70.000000      1.000000
# 50%    226215.000000     25.000000    181.000000     75.000000      1.000000
# 75%    240880.000000     29.000000    186.000000     80.000000      2.000000
# max    252905.000000     42.000000    205.000000    110.000000      4.000000
#
#             overall     potential     value_eur       wage_eur  \
# count  18483.000000  18483.000000  1.848300e+04   18483.000000
# mean      66.198885     71.500893  2.461422e+06    9563.084997
# std        6.950927      6.140787  5.557379e+06   21035.987405
# ...

# %%
player_sal=fifa[['short_name','wage_eur']]
player_sal
# Out:
#               short_name  wage_eur
# 0               L. Messi    575000
# 1      Cristiano Ronaldo    400000
# 2              Neymar Jr    300000
# 3               J. Oblak    120000
# 4              E. Hazard    475000
# ...                  ...       ...
# 18478         Shao Shuai      2000
# 18479       Xiao Mingjie      2000
# 18480          Zhang Wei      2000
# 18481       Wang Haijian      1000
# 18482         Pan Ximing      2000
#
# [18483 rows x 2 columns]

# %%
player_sal=player_sal.sort_values(by='wage_eur',ascending=False)
player_sal
# Out:
#               short_name  wage_eur
# 0               L. Messi    575000
# 4              E. Hazard    475000
# 1      Cristiano Ronaldo    400000
# 5           K. De Bruyne    375000
# 22          A. Griezmann    375000
# ...                  ...       ...
# 3932           O. Boumal         0
# 409            S. Ardero         0
# 18193           D. Arndt         0
# 4685     R. Sigurjónsson         0
# 5225            P. Anton         0
#
# [18483 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))
plt.bar(player_sal['short_name'][0:5],list(player_sal['wage_eur'][0:5]))
# Out:
# <BarContainer object of 5 artists>

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels           Mats Hummels   30  1988-12-16        191
#
#     weight_kg nationality          club_name  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...  33+3  41+3  41+3  41+3
# ...

# %%
Germany.sort_values(by=['height_cm'], ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 8044      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1219      200212  https://sofifa.com/player/200212/michael-esser...
# 1391      199833  https://sofifa.com/player/199833/lars-unnersta...
# 7525      205451  https://sofifa.com/player/205451/benedikt-rock...
# 4460      158657  https://sofifa.com/player/158657/thomas-kessle...
# ...          ...                                                ...
# 6379      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 18086     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 16110     247284  https://sofifa.com/player/247284/patrick-finge...
# 11460     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 11696     248879  https://sofifa.com/player/248879/kevin-holzwei...
#
#           short_name         long_name  age         dob  height_cm  weight_kg  \
# ...

# %%
Germany.sort_values(by='weight_kg', ascending=False).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 13693     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1391      199833  https://sofifa.com/player/199833/lars-unnersta...
# 519       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 13313     241388  https://sofifa.com/player/241388/dennis-smarsc...
# 165       213331  https://sofifa.com/player/213331/jonathan-tah/...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# 1219      200212  https://sofifa.com/player/200212/michael-esser...
# 2751      224251  https://sofifa.com/player/224251/robin-zentner...
# 5118      216284  https://sofifa.com/player/216284/florian-balla...
# 11775     208719  https://sofifa.com/player/208719/philipp-kuhn/...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13693   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# ...

# %%
Germany.sort_values(by='wage_eur', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 55        222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146       186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 37        188350  https://sofifa.com/player/188350/marco-reus/20...
# ...          ...                                                ...
# 15585     243801  https://sofifa.com/player/243801/dennis-dresse...
# 15444     240984  https://sofifa.com/player/240984/matti-langer/...
# 15316     216441  https://sofifa.com/player/216441/dejan-bozic/2...
# 18402     244172  https://sofifa.com/player/244172/matthis-harsm...
# 16888     248478  https://sofifa.com/player/248478/diant-ramaj/2...
#
#           short_name              long_name  age         dob  height_cm  \
# 36          T. Kroos             Toni Kroos   29  1990-01-04        183
# ...

# %%
Germany[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False)
# Out:
#           short_name  wage_eur
# 36          T. Kroos    325000
# 6      M. ter Stegen    250000
# 55           L. Sané    190000
# 146      I. Gündoğan    180000
# 37           M. Reus    170000
# ...              ...       ...
# 15585     D. Dressel       500
# 15444      M. Langer       500
# 15316       D. Bozic       500
# 18402     M. Harsman       500
# 16888       D. Ramaj         0
#
# [1218 rows x 2 columns]

# %%
shooting_ply=fifa[['short_name','shooting']]
shooting_ply
# Out:
#               short_name  shooting
# 0               L. Messi      92.0
# 1      Cristiano Ronaldo      93.0
# 2              Neymar Jr      85.0
# 3               J. Oblak       NaN
# 4              E. Hazard      83.0
# ...                  ...       ...
# 18478         Shao Shuai      23.0
# 18479       Xiao Mingjie      24.0
# 18480          Zhang Wei      35.0
# 18481       Wang Haijian      35.0
# 18482         Pan Ximing      32.0
#
# [18483 rows x 2 columns]

# %%
shooting_ply.sort_values(by='shooting',ascending=False)
# Out:
#                short_name  shooting
# 1       Cristiano Ronaldo      93.0
# 0                L. Messi      92.0
# 12                H. Kane      91.0
# 17              S. Agüero      90.0
# 206       F. Quagliarella      89.0
# ...                   ...       ...
# 18436         P. Królczyk       NaN
# 18444          V. Storsve       NaN
# 18456  G. Sykes-Kenworthy       NaN
# 18464          H. Sveijer       NaN
# 18477           P. Martin       NaN
#
# [18483 rows x 2 columns]

# %%
defending_ply=fifa[['short_name','defending','nationality','club_name']]
defending_ply.head()
# Out:
#           short_name  defending nationality            club_name
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
defending_ply.sort_values(by='defending',ascending=False)
# Out:
#                short_name  defending          nationality          club_name
# 16           G. Chiellini       90.0                Italy           Juventus
# 7             V. van Dijk       90.0          Netherlands          Liverpool
# 11           K. Koulibaly       89.0              Senegal             Napoli
# 35               D. Godín       89.0              Uruguay              Inter
# 49             M. Hummels       89.0              Germany  Borussia Dortmund
# ...                   ...        ...                  ...                ...
# 18436         P. Królczyk        NaN               Poland      Piast Gliwice
# 18444          V. Storsve        NaN               Norway      Lillestrøm SK
# 18456  G. Sykes-Kenworthy        NaN              England      Bradford City
# 18464          H. Sveijer        NaN               Sweden          IK Sirius
# 18477           P. Martin        NaN  Republic of Ireland       Waterford FC
#
# [18483 rows x 4 columns]

# %%
fifa.club_name
# Out:
# 0                         FC Barcelona
# 1                             Juventus
# 2                  Paris Saint-Germain
# 3                      Atlético Madrid
# 4                          Real Madrid
#                      ...
# 18478                 Beijing Renhe FC
# 18479                 Shanghai SIPG FC
# 18480           Hebei China Fortune FC
# 18481    Shanghai Greenland Shenhua FC
# 18482           Hebei China Fortune FC
# Name: club_name, Length: 18483, dtype: object

# %%
real_madrid=fifa[fifa['club_name']=='Real Madrid']
real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality    club_name  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
real_madrid.sort_values(by='wage_eur',ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 28        192119  https://sofifa.com/player/192119/thibaut-court...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# ...

# %%
real_madrid.sort_values(by='shooting', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 161       232432  https://sofifa.com/player/232432/luka-jovic/20...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 178       220834  https://sofifa.com/player/220834/marco-asensio...
# 637       221639  https://sofifa.com/player/221639/mariano-diaz-...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# 404       208618  https://sofifa.com/player/208618/lucas-vazquez...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# ...

# %%
real_madrid.sort_values(by='defending',ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 333       240130  https://sofifa.com/player/240130/eder-gabriel-...
# 278       200724  https://sofifa.com/player/200724/jose-ignacio-...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# 438       234035  https://sofifa.com/player/234035/alvaro-odrioz...
# 425       228618  https://sofifa.com/player/228618/ferland-mendy...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 2290      209749  https://sofifa.com/player/209749/lucas-silva-b...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 5688      244523  https://sofifa.com/player/244523/javier-hernan...
# ...

# %%
real_madrid.nationality.value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Colombia               1
# Wales                  1
# Croatia                1
# Japan                  1
# Serbia                 1
# Uruguay                1
# Germany                1
# Dominican Republic     1
# Costa Rica             1
# Name: nationality, dtype: int64
